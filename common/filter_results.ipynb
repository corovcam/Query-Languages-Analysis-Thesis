# %% [markdown]
# ## Experiment results postprocessing and filtering
#
# For each database (db), record volume (record_volume) and query type (query), we remove the iteration with the minimum and maximum execution time (time_in_seconds). We also process some inconsistencies and include additional labels to the data.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('results.csv')

df["old_time_in_seconds"] = df["time_in_seconds"].copy()

df
# Out:
#               db  record_volume query  iteration  time_in_seconds  \
# 0         sqlite           1000   1-1          0         0.001000
# 1         sqlite           1000   1-1          1         0.001000
# 2         sqlite           1000   1-1          2         0.001000
# 3         sqlite           1000   1-1          3         0.001000
# 4         sqlite           1000   1-1          4         0.001000
# ...          ...            ...   ...        ...              ...
# 12880  cassandra        1024000   9-2         16         0.001820
# 12881  cassandra        1024000   9-2         17         0.001939
# 12882  cassandra        1024000   9-2         18         0.003948
# 12883  cassandra        1024000   9-2         19         0.001888
# 12884  cassandra        1024000   9-2         20         0.001765
#
#        old_time_in_seconds
# 0                 0.001000
# 1                 0.001000
# 2                 0.001000
# 3                 0.001000
# 4                 0.001000
# ...                    ...
# 12880             0.001820
# 12881             0.001939
# 12882             0.003948
# 12883             0.001888
# 12884             0.001765
#
# [12885 rows x 6 columns]

# %%
df.drop(df[(df["db"] == "cassandra") & (df["record_volume"] != 1000) & (df["query"] == "3-1")].index, inplace=True)
df[(df["db"] == "cassandra") & (df["record_volume"] != 1000)]
# Out:
#               db  record_volume query  iteration  time_in_seconds  \
# 11224  cassandra           4000    10          1         0.001860
# 11225  cassandra           4000    10          2         0.002380
# 11226  cassandra           4000    10          3         0.002416
# 11227  cassandra           4000    10          4         0.002605
# 11228  cassandra           4000    10          5         0.002413
# ...          ...            ...   ...        ...              ...
# 12880  cassandra        1024000   9-2         16         0.001820
# 12881  cassandra        1024000   9-2         17         0.001939
# 12882  cassandra        1024000   9-2         18         0.003948
# 12883  cassandra        1024000   9-2         19         0.001888
# 12884  cassandra        1024000   9-2         20         0.001765
#
#        old_time_in_seconds
# 11224             0.001860
# 11225             0.002380
# 11226             0.002416
# 11227             0.002605
# 11228             0.002413
# ...                    ...
# 12880             0.001820
# 12881             0.001939
# 12882             0.003948
# 12883             0.001888
# 12884             0.001765
#
# [1600 rows x 6 columns]

# %%
df.loc[df["db"].isin(["mysql", "sqlite"]) & (df["query"] == "4-2"), "time_in_seconds"] = -1
df.loc[df["db"].isin(["mysql", "sqlite"]) & (df["query"] == "4-2")]
# Out:
#           db  record_volume query  iteration  time_in_seconds  \
# 260   sqlite           1000   4-2          0             -1.0
# 261   sqlite           1000   4-2          1             -1.0
# 262   sqlite           1000   4-2          2             -1.0
# 263   sqlite           1000   4-2          3             -1.0
# 264   sqlite           1000   4-2          4             -1.0
# ...      ...            ...   ...        ...              ...
# 3915   mysql         128000   4-2         17             -1.0
# 3916   mysql         128000   4-2         18             -1.0
# 3917   mysql         128000   4-2         19             -1.0
# 3918   mysql         128000   4-2         20             -1.0
# 4261   mysql        1024000   4-2          1             -1.0
#
#       old_time_in_seconds
# 260                  -1.0
# 261                  -1.0
# 262                  -1.0
# 263                  -1.0
# 264                  -1.0
# ...                   ...
# 3915                 -1.0
# 3916                 -1.0
# 3917                 -1.0
# 3918                 -1.0
# 4261                 -1.0
#
# [202 rows x 6 columns]

# %%
dnf = df[df["time_in_seconds"] < 0]
dnf
# Out:
#             db  record_volume query  iteration  time_in_seconds  \
# 260     sqlite           1000   4-2          0             -1.0
# 261     sqlite           1000   4-2          1             -1.0
# 262     sqlite           1000   4-2          2             -1.0
# 263     sqlite           1000   4-2          3             -1.0
# 264     sqlite           1000   4-2          4             -1.0
# ...        ...            ...   ...        ...              ...
# 10679  mongodb        1024000   3-1         -1             -1.0
# 10700  mongodb        1024000   3-3         -1             -1.0
# 10721  mongodb        1024000   4-1         -1             -1.0
# 10722  mongodb        1024000   4-2         -1             -1.0
# 10783  mongodb        1024000   8-1         -1             -1.0
#
#        old_time_in_seconds
# 260                   -1.0
# 261                   -1.0
# 262                   -1.0
# 263                   -1.0
# 264                   -1.0
# ...                    ...
# 10679                 -1.0
# 10700                 -1.0
# 10721                 -1.0
# 10722                 -1.0
# 10783                 -1.0
#
# [285 rows x 6 columns]

# %%
# df.drop(df[df["time_in_seconds"] < 0].index, inplace=True)
dropped_duplicate_dnf = df[df["time_in_seconds"] < 0].drop_duplicates(subset=["db", "record_volume", "query", "time_in_seconds"])
dropped_duplicate_dnf = dropped_duplicate_dnf.replace({"time_in_seconds": -1}, "DNF")

df = pd.concat([df.drop(dnf.index), dropped_duplicate_dnf]).sort_index()
df
# Out:
#               db  record_volume query  iteration time_in_seconds  \
# 0         sqlite           1000   1-1          0           0.001
# 1         sqlite           1000   1-1          1           0.001
# 2         sqlite           1000   1-1          2           0.001
# 3         sqlite           1000   1-1          3           0.001
# 4         sqlite           1000   1-1          4           0.001
# ...          ...            ...   ...        ...             ...
# 12880  cassandra        1024000   9-2         16         0.00182
# 12881  cassandra        1024000   9-2         17        0.001939
# 12882  cassandra        1024000   9-2         18        0.003948
# 12883  cassandra        1024000   9-2         19        0.001888
# 12884  cassandra        1024000   9-2         20        0.001765
#
#        old_time_in_seconds
# 0                 0.001000
# 1                 0.001000
# 2                 0.001000
# 3                 0.001000
# 4                 0.001000
# ...                    ...
# 12880             0.001820
# 12881             0.001939
# 12882             0.003948
# 12883             0.001888
# 12884             0.001765
#
# [12615 rows x 6 columns]

# %%
df[df["time_in_seconds"] == "DNF"]
# Out:
#             db  record_volume query  iteration time_in_seconds  \
# 260     sqlite           1000   4-2          0             DNF
# 660     sqlite           4000   4-2          1             DNF
# 960     sqlite         256000   3-1          1             DNF
# 981     sqlite         256000   3-3          1             DNF
# 1002    sqlite         256000   4-1          1             DNF
# ...        ...            ...   ...        ...             ...
# 10679  mongodb        1024000   3-1         -1             DNF
# 10700  mongodb        1024000   3-3         -1             DNF
# 10721  mongodb        1024000   4-1         -1             DNF
# 10722  mongodb        1024000   4-2         -1             DNF
# 10783  mongodb        1024000   8-1         -1             DNF
#
#        old_time_in_seconds
# 260                   -1.0
# 660                   -1.0
# 960                   -1.0
# 981                   -1.0
# 1002                  -1.0
# ...                    ...
# 10679                 -1.0
# 10700                 -1.0
# 10721                 -1.0
# 10722                 -1.0
# 10783                 -1.0
#
# [76 rows x 6 columns]

# %%
gb = df.groupby(["db", "record_volume", "query"])["time_in_seconds"]
gb.describe()
# Out:
#                              count unique       top freq
# db       record_volume query
# arangodb 1000          1-1    20.0   20.0  0.001766  1.0
#                        1-2    20.0   20.0  0.001571  1.0
#                        1-3    20.0   20.0   0.00049  1.0
#                        1-4    20.0   20.0  0.005032  1.0
#                        10     20.0   20.0  0.030094  1.0
# ...                            ...    ...       ...  ...
# sqlite   1024000       6      20.0   20.0    28.437  1.0
#                        7      20.0   20.0    25.457  1.0
#                        8      20.0   18.0      2.34  2.0
#                        9-1    20.0   19.0      2.64  2.0
#                        9-2    20.0   18.0      2.01  2.0
#
# [703 rows x 4 columns]

# %%
idxmin = gb.idxmin()
df.loc[idxmin]
# Out:
#             db  record_volume query  iteration time_in_seconds  \
# 6513  arangodb           1000   1-1         17        0.000414
# 6529  arangodb           1000   1-2         13        0.001397
# 6541  arangodb           1000   1-3          5         0.00025
# 6574  arangodb           1000   1-4         18         0.00142
# 6874  arangodb           1000    10         18        0.029474
# ...        ...            ...   ...        ...             ...
# 2060    sqlite        1024000     6          8          19.329
# 2087    sqlite        1024000     7         15          21.819
# 2093    sqlite        1024000     8          1           2.141
# 2132    sqlite        1024000   9-1         20           2.612
# 2145    sqlite        1024000   9-2         13           1.459
#
#       old_time_in_seconds
# 6513             0.000414
# 6529             0.001397
# 6541             0.000250
# 6574             0.001420
# 6874             0.029474
# ...                   ...
# 2060            19.329000
# 2087            21.819000
# 2093             2.141000
# 2132             2.612000
# 2145             1.459000
#
# [703 rows x 6 columns]

# %%
idxmax = gb.idxmax()
df.loc[idxmax]
# Out:
#             db  record_volume query  iteration time_in_seconds  \
# 6496  arangodb           1000   1-1          0        0.001766
# 6531  arangodb           1000   1-2         15        0.002755
# 6543  arangodb           1000   1-3          7        0.000558
# 6556  arangodb           1000   1-4          0        0.005032
# 6865  arangodb           1000    10          9        0.036892
# ...        ...            ...   ...        ...             ...
# 2053    sqlite        1024000     6          1          28.437
# 2073    sqlite        1024000     7          1          25.457
# 2108    sqlite        1024000     8         16           2.369
# 2117    sqlite        1024000   9-1          5            3.71
# 2146    sqlite        1024000   9-2         14           2.082
#
#       old_time_in_seconds
# 6496             0.001766
# 6531             0.002755
# 6543             0.000558
# 6556             0.005032
# 6865             0.036892
# ...                   ...
# 2053            28.437000
# 2073            25.457000
# 2108             2.369000
# 2117             3.710000
# 2146             2.082000
#
# [703 rows x 6 columns]

# %%
df["time_in_seconds"] = df["time_in_seconds"].loc[(~df.index.isin(idxmin) & ~df.index.isin(idxmax)) | (df["time_in_seconds"] == "DNF")]
df["extra_label"] = df["time_in_seconds"][df["time_in_seconds"] == "DNF"].copy()
df.replace({"time_in_seconds": "DNF"}, 300, inplace=True)
df
# Out:
# C:\Users\marti\AppData\Local\Temp\ipykernel_30840\1051173903.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({"time_in_seconds": "DNF"}, 300, inplace=True)
#               db  record_volume query  iteration  time_in_seconds  \
# 0         sqlite           1000   1-1          0              NaN
# 1         sqlite           1000   1-1          1         0.001000
# 2         sqlite           1000   1-1          2         0.001000
# 3         sqlite           1000   1-1          3         0.001000
# 4         sqlite           1000   1-1          4         0.001000
# ...          ...            ...   ...        ...              ...
# 12880  cassandra        1024000   9-2         16         0.001820
# 12881  cassandra        1024000   9-2         17         0.001939
# 12882  cassandra        1024000   9-2         18              NaN
# 12883  cassandra        1024000   9-2         19         0.001888
# 12884  cassandra        1024000   9-2         20              NaN
#
#        old_time_in_seconds extra_label
# 0                 0.001000         NaN
# 1                 0.001000         NaN
# 2                 0.001000         NaN
# 3                 0.001000         NaN
# 4                 0.001000         NaN
# ...                    ...         ...
# 12880             0.001820         NaN
# 12881             0.001939         NaN
# 12882             0.003948         NaN
# 12883             0.001888         NaN
# 12884             0.001765         NaN
#
# [12615 rows x 7 columns]

# %%
df.loc[(df["db"] == "mongodb") & (df["record_volume"] >= 256000) & (df["query"] == "3-1"), "extra_label"] = "DNF,#1"
df.loc[(df["db"] == "mongodb") & (df["record_volume"] >= 256000) & (df["query"] == "4-2"), "extra_label"] = "DNF,#2"

# %%
df.to_csv('results_filtered.csv', index=False)
